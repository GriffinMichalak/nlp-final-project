# %%
import helpers as helpers

path1 = "data/depression_dataset_reddit_cleaned.csv"

data_word = helpers.read_file(datapath=path1, ngram=2, by_character=False)
data_char = helpers.read_file(datapath=path1, ngram=2, by_character=True)

helpers.get_analytics(data_word, by_character=False)
helpers.get_analytics(data_char, by_character=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/griffinmichalak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Number of texts:  7731
# Number of sentences:  7731
# Number of tokens:  592561
# Vocabulary (By Word):  18850
# Vocabulary (By Char):  32
