# %%
import helpers as helpers
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/griffinmichalak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/griffinmichalak/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/griffinmichalak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
names = [
    "TF-IDF with Logistic Regression",
    "Linear SVM",
    "Multinomial Naive Bayes", # no graphs added yet for this
    "BERT",
]

# %% [markdown]
# ## Metrics Comparison Table

# %%
import pandas as pd

df = pd.read_csv('results/results.csv')
df
# Out:
#      model  precision    recall        f1  accuracy    pr_auc   roc_auc
# 0   tf_idf   0.964187  0.940860  0.952381  0.954780  0.989268  0.988020
# 1   linear   0.971279  0.948980  0.960000  0.959897  0.989049  0.986736
# 2     bert   0.960630  0.983871  0.972112  0.972868  0.998001  0.998034
# 3   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973846  0.969544
# 4   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973846  0.969544
# 5   tf_idf   0.964187  0.940860  0.952381  0.954780  0.989268  0.988020
# 6   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973846  0.969544
# 7   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973846  0.969544
# 8   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973846  0.969544
# 9   tf_idf   0.926027  0.908602  0.917232  0.921189  0.973274  0.969163
# 10  tf_idf   0.920765  0.905914  0.913279  0.917313  0.972306  0.968193
# 11  tf_idf   0.916898  0.889785  0.903138  0.908269  0.968709  0.963670
# ...

# %% [markdown]
# ## Show Graphs & Compare

# %%
# show confusion matrices
confusion_imgs = [
    "results/tf_idf/confusion_tf_idf.png",
    "results/linear/confusion_linear.png",
    # TODO: add NB image
    "results/bert/confusion_dev_bert.png",
    "results/bert/confusion_test_bert.png",
]

helpers.show_image_group(confusion_imgs, title="Confusion Matrices for All Models", rows=2, cols=3)

# %%
# show learning curve images
learning_imgs = [
    "results/tf_idf/learning_curve_tf_idf.png",
    "results/linear/learning_curve_linear.png",
    # TODO: add NB image
    "results/bert/learning_curve_bert.png",
]

helpers.show_image_group(learning_imgs, title="Learning Curves for All Models", rows=2, cols=2)

# %%
# show precision-recall
pr_imgs = [
    "results/tf_idf/pr_tf_idf.png",
    "results/linear/pr_linear.png",
    # TODO: add NB image
    "results/bert/pr_dev_bert.png",
]

helpers.show_image_group(pr_imgs, title="Precision-Recall For all Models for All Models", rows=2, cols=2)

# %%
# show most associated with dep
pr_imgs = [
    "results/tf_idf/most_tf_idf.png",
    "results/linear/most_linear.png",
    # TODO: add NB image
    "results/bert/most_bert.png",
]

helpers.show_image_group(pr_imgs, title="Most Assoc. Depression", rows=2, cols=2)

# %%
# show least associated with dep
pr_imgs = [
    "results/tf_idf/least_tf_idf.png",
    "results/linear/least_linear.png",
    # TODO: add NB image
    "results/bert/least_bert.png",
]

helpers.show_image_group(pr_imgs, title="Least Assoc. Depression", rows=2, cols=2)

# %%
# TODO: display all ablations here
