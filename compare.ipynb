# %%
from sklearn.datasets import make_circles, make_classification, make_moons
import helpers as helpers

# %%
names = [
    "TF-IDF with Logistic Regression",
    "Linear SVM",
    "Multinomial Naive Bayes",
    "BERT",
]
print(helpers.RESULTS)
# Out:
# {}
