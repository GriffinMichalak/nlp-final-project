# %%
import helpers as helpers
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/griffinmichalak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DEPRESSION_PATH = "data/depression_dataset_reddit_cleaned.csv"
N_GRAM = 2

# %%
clean_text, is_depression = helpers.get_data(datapath=DEPRESSION_PATH, ngram=N_GRAM, tokenize=True, by_character=False)

data = list(zip(clean_text, is_depression))
helpers.get_stats(data)
# Out:
# ======================================================================
# Number of lines: 7731
# Number of tokens: 592561
# Number of unique tokens: 18850
# Number of YES depression entries: 3831 (49.55%)
# Number of NOT depression entries: 3900 (50.45%)
# ======================================================================
